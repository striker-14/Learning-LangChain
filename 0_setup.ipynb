# %% [markdown]
# ##### 1. Install dependencies

# %%
uv python pin 3.11
uv init
uv add langchain
uv sync

# %% [markdown]
# ##### 2. Set up API keys

# %%
GOOGLE_API_KEY="your-api-key"

# %%
uv add langchain-google-genai

# %% [markdown]
# ##### To load a .env file, use python-dotenv (load_dotenv()).

# %%
uv add python-dotenv

# %%
from dotenv import load_dotenv

load_dotenv()
